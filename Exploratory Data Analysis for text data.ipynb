# %%
"""
we will use Womens Clothing E-Commerce Reviews data set, and try to explore and visualize as much as we can, using Plotly’s Python graphing library and Bokeh
 visualization library. Not only we are going to explore text data, but also we will visualize numeric and categorical features.


"""
# Out:
# '\nwe will use Womens Clothing E-Commerce Reviews data set, and try to explore and visualize as much as we can, using Plotly’s Python graphing library and Bokeh\n visualization library. Not only we are going to explore text data, but also we will visualize numeric and categorical features.\n\n\n'

# %%
import pandas as pd

# %%
df = pd.read_csv('Womens Clothing E-Commerce Reviews.csv')

# %%
# remove the title feature and unnamed feature
df.drop('Unnamed: 0', axis=1, inplace=True)
df.drop('Title', axis=1, inplace=True)

# %%
df.describe()
# Out:
#         Clothing ID           Age        Rating  Recommended IND  \
# count  23486.000000  23486.000000  23486.000000     23486.000000
# mean     918.118709     43.198544      4.196032         0.822362
# std      203.298980     12.279544      1.110031         0.382216
# min        0.000000     18.000000      1.000000         0.000000
# 25%      861.000000     34.000000      4.000000         1.000000
# 50%      936.000000     41.000000      5.000000         1.000000
# 75%     1078.000000     52.000000      5.000000         1.000000
# max     1205.000000     99.000000      5.000000         1.000000
#
#        Positive Feedback Count
# count             23486.000000
# mean                  2.535936
# std                   5.702202
# min                   0.000000
# 25%                   0.000000
# 50%                   1.000000
# 75%                   3.000000
# max                 122.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23486 entries, 0 to 23485
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Clothing ID              23486 non-null  int64
#  1   Age                      23486 non-null  int64
#  2   Review Text              22641 non-null  object
#  3   Rating                   23486 non-null  int64
#  4   Recommended IND          23486 non-null  int64
#  5   Positive Feedback Count  23486 non-null  int64
#  6   Division Name            23472 non-null  object
#  7   Department Name          23472 non-null  object
#  8   Class Name               23472 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 1.6+ MB

# %% [markdown]
# # Preprocessing and text cleaning

# %%
# preprocess function

def preprocess(ReviewText):

    # getting rids of tags
    ReviewText = ReviewText.str.replace("(<br/>)", "")
    ReviewText = ReviewText.str.replace('(<a).*(>).*(</a>)', '')
    ReviewText = ReviewText.str.replace('(&amp)', '')
    ReviewText = ReviewText.str.replace('(&gt)', '')
    ReviewText = ReviewText.str.replace('(&lt)', '')
    ReviewText = ReviewText.str.replace('(\xa0)', ' ')  
    return ReviewText

# %%
#now we will apply preprocess then we will extract 2 feature from Revuew data length and no of words

# sentiment library textblob
from textblob import TextBlob

# %%
df['Review Text'] = preprocess(df['Review Text'])

df['polarity'] = df['Review Text'].map(lambda text: TextBlob(str(text)).sentiment.polarity)
df['review_len'] = df['Review Text'].astype(str).apply(len)
df['word_count'] = df['Review Text'].apply(lambda x: len(str(x).split()))

# %%
import plotly

import cufflinks as cf
cf.go_offline()
cf.set_config_file(offline=False, world_readable=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# #  Polarity Visualization

# %%
df['polarity'].iplot(
    kind='hist',
    bins=50,
    xTitle='polarity',
    linecolor='black',
    yTitle='count',
    title='Sentiment Polarity Distribution')
# Out:
# <div>                            <div id="b3667ccb-76aa-439e-9e29-de8b237753df" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # distribution of review ratings

# %%
df['Rating'].iplot(
    kind='hist',
    xTitle='rating',
    linecolor='black',
    yTitle='count',
    title='Review Rating Distribution')
# Out:
# <div>                            <div id="ecea2506-29c9-49ba-8a08-f29f6ed5c206" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # text lenghts

# %%
df['review_len'].iplot(
    kind='hist',
    bins=100,
    xTitle='review length',
    linecolor='black',
    yTitle='count',
    title='Review Text Length Distribution')
# Out:
# <div>                            <div id="6999a930-b971-4e1b-aa73-2d3793137250" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # Department distribution

# %%
df.groupby('Department Name').count()['Clothing ID'].sort_values(ascending=False).iplot(kind='bar', yTitle='Count', linecolor='black', opacity=0.8,
                                                           title='Bar chart of Department Name', xTitle='Department Name')
# Out:
# <div>                            <div id="7e620986-53be-419a-b425-8b8fc5db9905" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# # The distribution of top unigrams after removing stop words

# %%
from sklearn.feature_extraction.text import CountVectorizer
import numpy as np

# %%
def get_top_n_words(corpus, n=1):
    vec = CountVectorizer(stop_words = 'english').fit(corpus)
    bag_of_words = vec.transform(corpus)
    sum_words = bag_of_words.sum(axis=0) 
    words_freq = [(word, sum_words[0, idx]) for word, idx in vec.vocabulary_.items()]
    words_freq =sorted(words_freq, key = lambda x: x[1], reverse=True)
    return words_freq[:n]

# %% [markdown]
# # Top part of speech Tags

# %%
|

# %%
blob = TextBlob(str(df['Review Text']))
pos_df = pd.DataFrame(blob.tags, columns = ['word' , 'pos'])
pos_df = pos_df.pos.value_counts()[:20]
pos_df.iplot(
    kind='bar',
    xTitle='POS',
    yTitle='count', 
    title='Top 20 Part-of-speech tagging for review corpus')
# Out:
# <div>                            <div id="884d9cc8-2460-40e8-a6a0-35a5bef0e5de" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...
